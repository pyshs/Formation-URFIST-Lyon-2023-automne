# %% [markdown]
# # Scrapping
#
# **Objectif** : Récupérer la page web de votre établissement de rattachement et vérifier si on parle de science ouverte

# %% [markdown]
# ## Les étapes
#
# - récupérer la page
# - tester la présence de mots clés sur la page
# - renvoyer le résultat

# %% [markdown]
# ## Récupérer une page web

# %%
import urllib.request

# %% [markdown]
# Plutôt utiliser la bibliothèque requests

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Différentes manières d'importer

# %%
import requests

# %%
import requests as rq

# %%
from requests import get

# %%
import requests

# %%
type(rq)
# Out:
# module

# %% [markdown]
# Tester la bibliothèque

# %%
page = requests.get('https://www.lemonde.fr/').text

# %%
type(r)
# Out:
# requests.models.Response

# %%
liste_urls = ["https://www.sciencespo.fr/fr/","https://www.univ-amu.fr/"]
kw = ["science ouverte","open science"]
for u in liste_urls:
    page = requests.get(u)
    texte = page.text.lower()
    print(u,texte.count(kw[0]))
# Out:
# https://www.sciencespo.fr/fr/ 0
# https://www.univ-amu.fr/ 1

# %%
import bs4

# %%
print(bs4.BeautifulSoup(texte,from_encoding="utf-8").text)
# Out:
# accueil | aix-marseille université
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   aller au contenu principal
#
#
#
#
# aix-marseille université :explorer pour faire société
#
#
#
#
#
# aix-marseille université,
# explorer pour faire société
# découvrir la vidéo
#
#
#
#
#
#
#
#
#
# top menu
#
#
# accueil
#
#
# intramu
#
#
# elections
#
#
# annuaire amu
#
#
# recrutement
#
#
# hrs4r
#
#
# civis
#
#
# we4lead
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# englishfrançais
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# navigation principale
#
#
#
# université
#
#
# présentation
#
#
# aix-marseille université
#
#
# organisation
#
#
# composantes
#
#
# instituts d'établissement & eurs
#
#
# institut d'études avancées - iméra
#
#
# développement durable
#
#
# biodiversité
#
#
# égalité des chances amu
#
#
# ...
